# %%
import pandas as pd

# %%
df = pd.read_csv('case_verdicts_v4.csv')

# %%
df.head()
# Out:
#    Column Applicant                                          Defendant  \
# 0       0     State                           Zibi 2008 JDR 0880 (BHC)
# 1       1     State                           Nkosi 2016 JDR 0568 (GJ)
# 2       2     State                           Nkosi 2016 JDR 0567 (GP)
# 3       3     Savoi  National Director of Public Prosecutions 2014 ...
# 4       4     State  Schoombee 2017 JDR 0054 (CC) \'97 Now reported...
#
#                     Case No  \
# 0                 CA&R 1/97
# 1                 CC98/2012
# 2                 CC98/2012
# 3    CCT 71/13[2014] ZACC 5
# 4  CCT 154/16[2016] ZACC 50
#
#                                               Judges  \
# 0                               Ebrahim J, Pickard J
# 1                                      DSS Moshidi J
# 2                                      DSS Moshidi J
# 3  Moseneke ACJ and Skweyiya ADCJ and Cameron J a...
# 4  Nkabinde ACJ and Cameron J, Froneman J, Jafta ...
#
# ...

# %%
df.drop('Column', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1812 entries, 0 to 1811
# Data columns (total 16 columns):
# Applicant           1811 non-null object
# Defendant           1809 non-null object
# Case No             1812 non-null object
# Judges              1812 non-null object
# Summary             1812 non-null object
# Date Heard          1489 non-null object
# Date Judgement      1709 non-null object
# Court               1812 non-null object
# Case Category       1812 non-null object
# Province            1812 non-null object
# Related Crimes 1    984 non-null object
# Related Crimes 2    217 non-null object
# Related Crimes 3    27 non-null object
# Related Crimes 4    1 non-null object
# Verdict 1           1287 non-null object
# Years Amount        490 non-null float64
# dtypes: float64(1), object(15)
# memory usage: 226.6+ KB

# %%
court_verdicts = df['Years Amount'].groupby(df['Court']).mean()

# %%
court_verdicts
# Out:
# Court
# Bhisho Division              22.333333
# Bloemfontein Division        17.309524
# Cape Town Division           14.071429
# Constitutional Court               NaN
# Durban Division              29.500000
# East London Division         25.000000
# Ermelo Division              40.000000
# Grahamstown Division         17.365217
# Johannesburg Division        16.325301
# Kimberley Division           15.066667
# Mahikeng Division            16.714286
# Middelburg Division          25.000000
# Mkobola Division             36.000000
# Mossel Bay Division                NaN
# Mthatha Division             22.333333
# Mtunzini Division                  NaN
# Pietermaritzburg Division    16.113208
# Port Elizabeth Division      21.529412
# South Gauteng Division       28.040000
# Supreme Court of Appeal      19.061538
# Thohoyandou Division          1.000000
# Witwatersrand Division             NaN
# Name: Years Amount, dtype: float64
